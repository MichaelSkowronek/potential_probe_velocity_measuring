# %% [markdown]
# # TODO
# - ESN
#     - one-point 2D
#     - note: echoTorch for GPUs (non-maintained)
# - Train for one point on the whole input
# - Go to your actual task!?
# - Presentation Inputs:
#     - Correlation between J and v => one unknown?
#     - Taken's Theorem (Well spaced time measurements determine position on attractor, this yields state)
#     - SHRED (Implicit Taken's)
#     - Reservoir (Extend state indefinitely to fulfil Taken's Theorem)
#     - Additional Measurements e.g. Temp, pressure
#     - Boundary Conditions
#     - Physical Conditions
# - Predicting one point
#     - whole plane
#     - CV?
#     - NN
#     - point output (problem independent)
#     - Can we learn more from learning on all prediction points? (=> more data + harder problem) ++ spacing needs to be a feature, because it is not uniform
#     - whole plane output (problem dependent)
# - Predicting multiple points in spacetime
#     - this is the final goal, so the model should be given the freedom to predict consistent outputs, which fits the actual data consistency and should yield better results.
#     - kernel output (problem independent)
#     - whole plane output (problem dependent)
# - Generalization loss variance (Bootstrapping, CV, learn about sklearn time series CV)?
# - u_y?
# - Validation with experiment data (from all sources there are)
# - does the non-uniformity change results?
# - SHRED relevant?:
# 		\begin{itemize}
# 			\item https://arxiv.org/abs/2405.11955
#
# 			\item https://arxiv.org/abs/2501.13329
#
# 			\item https://arxiv.org/abs/2502.10930
#
# 			\item https://royalsocietypublishing.org/doi/10.1098/rspa.2024.0054
# 		\end{itemize}
#
# ##### Optional
# - Calculate experiment delta_l_y
#
# ##### Dmitry Q&A:
# - Important: Can we measure additional things in addition to potentials?
# - Do we have the partial derivative of the potential for the 3D data?
# - $\mathrm{Ha} = 300$ implies a relation between system properties. How to determine $B$ and $\sigma$ for Ohm's law? According to the data, they must be as I have calculated. Am I right?
# - $\sigma = -1$ + $B = -1$? Where is the error?
# - median(sigma_est) in x direction (sigma_and_b) is not -1 everywhere. I suspect numerical errors. What do you think?
# - Why is there an error, even if I use $\frac{\partial{\phi}}{\partial{y}}$ from the simulation?
# - Where is the experimental data for validation
