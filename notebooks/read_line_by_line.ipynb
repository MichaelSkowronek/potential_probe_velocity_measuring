# %% [markdown]
# # Read Line by Line
#
# For peeking into huge files.

# %% [markdown]
# ### Imports

# %%
from pathlib import Path


from python_utils.data_processing import read_first_n_lines

# %% [markdown]
# ### Main

# %%
Ha = 300

if Ha == 300:
    simulation_dir_path = Path("../../../data/4pi_re1000_ha300.360_ch28.p1/")
elif Ha == 1000:
    simulation_dir_path = Path("../../../data/4pi_re1000_ha1000.384.pi/")

data_path_suffix = Path("patt_fld8v/patt_fld8v.dat")

file_path = simulation_dir_path / data_path_suffix

# %%
read_first_n_lines(
    file_path,
    10,
    )
# Out:
# ['title = "Fields 3D"',
#  'variables = "x", "y", "z", "vx", "vy", "vz", "jx", "jy", "jz", "P", "F"',
#  'zone i=         541 , j=          91 , k=          91 , f=point',
#  '0.000000E+00 -1.000000E+00 -1.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00 -1.464999E-19  0.000000E+00  0.000000E+00 -4.031829E-04  1.353023E+00',
#  '2.327106E-02 -1.000000E+00 -1.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00  8.869907E-02  0.000000E+00  0.000000E+00 -3.996179E-04  1.352057E+00',
#  '4.654211E-02 -1.000000E+00 -1.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00  1.778942E-01  0.000000E+00  0.000000E+00 -3.986544E-04  1.348849E+00',
#  '6.981317E-02 -1.000000E+00 -1.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00  1.965593E-01  0.000000E+00  0.000000E+00 -4.007815E-04  1.344313E+00',
#  '9.308423E-02 -1.000000E+00 -1.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00  1.472270E-01  0.000000E+00  0.000000E+00 -4.046824E-04  1.340216E+00',
# ...
